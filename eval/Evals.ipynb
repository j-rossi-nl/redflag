# %%
import pandas as pd

# %%
df = pd.read_csv('CRF/paper_report.csv')

# %%
df['model'] = 'CRF'

# %%
df2 = pd.read_csv('Albert_AddPT/paper_report.csv')

# %%
df2['model'] = 'Albert_AddPT'

# %%
val = pd.concat([df, df2], ignore_index=True).reset_index().drop(columns=['support', 'index'])

val['Entity'] = val['Unnamed: 0']
val = val.drop(columns=['Unnamed: 0'])

# %%
val.set_index('Entity').plot.barh(figsize=(12, 12))

# %%
pd.plotting.parallel_coordinates(val[['model', 'recall', 'precision']], 'model')

# %%
for i, d in grp:
